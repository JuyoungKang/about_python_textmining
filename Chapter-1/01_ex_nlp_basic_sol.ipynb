# %% [markdown]
# # 텍스트 파일 핸들링

# %% [markdown]
# ### 1. data/signal.txt 파일을 읽어서 출력하기

# %%
# %ls
# Out:
# 01_Natural_Language_Basics.ipynb  data/
# 01_ex_nlp_basic_sol.ipynb         figures/
# corpora_demo.py

# %%
# %ls data
# Out:
# signal.txt

# %%
with open('data/signal.txt') as f :
    for line in f : 
        print(line.strip())
# Out:
# Trying to let you know
# Sign을 보내 signal 보내
# I must let you know
# Sign을 보내 signal 보내
# Sign을 보내 signal 보내
# Sign을 보내 signal 보내
# Sign을 보내 signal 보내
# I must let you know
# Sign을 보내 signal 보내
# 근데 전혀 안 통해
# 눈빛을 보내 눈치를 주네
# 근데 못 알아듣네
# 답답해서 미치겠다 정말
# 왜 그런지 모르겠다 정말
# 다시 한 번 힘을 내서
# Sign을 보내 signal 보내
# 눈짓도 손짓도 어떤 표정도
# 소용이 없네 하나도 안 통해
# 눈치도 코치도 전혀 없나 봐
# 더 이상 어떻게 내 맘을 표현해
# 언제부턴가 난 네가 좋아
# 지기 시작했어 바보야
# 왜 이렇게도 내 맘을 몰라
# 언제까지 이렇게 둔하게
# 나를 친구로만 대할래
# 내가 원하는 건 그게 아닌데
# Signal 보내 signal 보내
# 찌릿 찌릿 찌릿 찌릿
# 난 너를 원해 난 너를 원해
# 왜 반응이 없니
# 만날 때 마다 마음을 담아
# 찌릿 찌릿 찌릿 찌릿
# 기다리잖아 다 보이잖아
# 왜 알지 못하니
# Trying to let you know
# Sign을 보내 signal 보내
# I must let you know
# Sign을 보내 signal 보내
# 널 보며 웃으면 알아채야지
# 오늘만 몇 번째 널 보며 웃는데
# 자꾸 말을 걸면 좀 느껴야지
# 계속 네 곁에 머물러있는데
# 언제부턴가 난 네가 좋아
# 지기 시작했어 바보야
# 왜 이렇게도 내 맘을 몰라
# 언제까지 이렇게 둔하게
# 나를 친구로만 대할래
# 내가 원하는 건 그게 아닌데
# Signal 보내 signal 보내
# 찌릿 찌릿 찌릿 찌릿
# 난 너를 원해 난 너를 원해
# 왜 반응이 없니
# 만날 때 마다 마음을 담아
# 찌릿 찌릿 찌릿 찌릿
# 기다리잖아 다 보이잖아
# 왜 알지 못하니
# 찌릿 찌릿 찌릿 찌릿
# 왜 반응이 없니
# 찌릿 찌릿 찌릿 찌릿
# 왜 알지 못하니
# Sign을 보내 signal 보내
# 근데 전혀 안 통해
# 눈빛을 보내 눈치를 주네
# 근데 못 알아듣네
# 답답해서 미치겠다 정말
# 왜 그런지 모르겠다 정말
# 다시 한 번 힘을 내서
# Sign을 보내 signal 보내

# %% [markdown]
# ------------------------

# %% [markdown]
# # 파이썬으로 영어와 한국어 텍스트 다루기

# %% [markdown]
# #### 참고자료 [1] 파이썬으로 영어와 한국어 텍스트 다루기

# %% [markdown]
# #### Text analysis process
#
# <img src="https://www.lucypark.kr/courses/2015-dm/images/text-process.png"  width= 300 />
#
# # 전처리는 아래의 세부 과정으로 다시 한 번 나뉜다.
# 1. Load text
# 2. Tokenize text (ex: stemming, morph analyzing)
# 3. Tag tokens (ex: POS, NER)
# 4. Token(Feature) selection and/or filter/rank tokens (ex: stopword removal, TF-IDF)
# 5. ...and so on (ex: calculate word/document similarities, cluster documents)

# %% [markdown]
# ## A. 자연어처리를 위한 파이썬 패키지 준비 & Load text

# %% [markdown]
# ### 1) 영어 자연어처리를 위한 nltk 설치하기

# %%
# 설치하기

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages
# Requirement already satisfied: six in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages (from nltk)

# %%
# Text corpora 다운로드 (아래의 두 데이터 다운로드하자)
# gutenberg
# maxent_treebank_pos_tagger

# %%
import nltk

nltk.download('gutenberg')
nltk.download('maxent_treebank_pos_tagger')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/moodern/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package maxent_treebank_pos_tagger to
# [nltk_data]     /Users/moodern/nltk_data...
# [nltk_data]   Package maxent_treebank_pos_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ### 2) 한글 자연어처리를 위한 konlpy 설치하기

# %%
# 설치하기

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages

# %%
# !pip install jpype1
# Out:
# Requirement already satisfied: jpype1 in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages

# %% [markdown]
# ### 3) 토픽 모델링을 위한 gensim 설치하기

# %%
# 설치하기

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages
# Requirement already satisfied: numpy>=1.11.3 in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages (from gensim)
# Requirement already satisfied: six>=1.5.0 in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages (from gensim)
# Requirement already satisfied: scipy>=0.18.1 in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages (from gensim)
# Requirement already satisfied: smart-open>=1.2.1 in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages (from gensim)
# Requirement already satisfied: bz2file in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim)
# Requirement already satisfied: requests in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim)
# Requirement already satisfied: boto>=2.32 in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages (from requests->smart-open>=1.2.1->gensim)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages (from requests->smart-open>=1.2.1->gensim)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages (from requests->smart-open>=1.2.1->gensim)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/moodern/anaconda/envs/about_python_textmining/lib/python3.6/site-packages (from requests->smart-open>=1.2.1->gensim)

# %% [markdown]
# ## B. Text exploration

# %% [markdown]
# ### 1) Read document

# %% [markdown]
# * 실습은 이 데이터들을 사용한다.
#     - 영어: Jane Austen의 소설 Emma
#     - 한국어 1: 대한민국 국회 제 1809890호 의안
#     - 한국어 2: 트와이스의 시그널 가사

# %%
# 영어 데이터 로딩
# files_en = austen-emma.txt
# doc_en

# %%
from nltk.corpus import gutenberg   # Docs from project gutenberg.org
files_en = gutenberg.fileids()      # Get file ids

# %%
files_en
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
doc_en = gutenberg.open('austen-emma.txt').read()

# %%
doc_en[:100]
# Out:
# '[Emma by Jane Austen 1816]\n\nVOLUME I\n\nCHAPTER I\n\n\nEmma Woodhouse, handsome, clever, and rich, with a'

# %%
# 한국어 1 데이터 로딩
# files_ko_pol = "1809890.txt"
# doc_ko_pol

# %%
from konlpy.corpus import kobill    # Docs from pokr.kr/bill
files_ko_pol = kobill.fileids()         # Get file ids

# %%
files_ko_pol
# Out:
# ['1809890.txt',
#  '1809891.txt',
#  '1809892.txt',
#  '1809893.txt',
#  '1809894.txt',
#  '1809895.txt',
#  '1809896.txt',
#  '1809897.txt',
#  '1809898.txt',
#  '1809899.txt']

# %%
doc_ko_pol = kobill.open('1809890.txt').read()

# %%
doc_ko_pol[:100]
# Out:
# '지방공무원법 일부개정법률안\n\n(정의화의원 대표발의 )\n\n 의 안\n 번 호\n\n9890\n\n발의연월일 : 2010.  11.  12.  \n\n발  의  자 : 정의화․이명수․김을동 \n\n이'

# %%
# 한국어 2 데이터 로딩
# files_ko_sig = 'signal.txt'
# doc_ko_sig

# %%
with open('data/signal.txt') as f :
    doc_ko_sig = f.read()

# %%
doc_ko_sig[:100]
# Out:
# 'Trying to let you know\nSign을 보내 signal 보내\nI must let you know\nSign을 보내 signal 보내\nSign을 보내 signal 보내\n'

# %% [markdown]
# ### 2) Tokenize

# %% [markdown]
# 문서를 토큰으로 나누는 방법은 다양하다. 여기서는 영어에는 nltk.regexp_tokenize, 한국어에는 konlpy.tag.Kkma.morph를 사용해보자.

# %%
# 영어

# %%
# 한글 1

# %%
# 한글 2

# %%
from nltk import regexp_tokenize
pattern = r'''(?x) ([A-Z]\.)+ | \w+(-\w+)* | \$?\d+(\.\d+)?%? | \.\.\. | [][.,;"'?():-_`]'''
tokens_en = regexp_tokenize(doc_en, pattern)

# %%
tokens_en
# Out:
# [('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '-one', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '-day', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '-people', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '-denying', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '-informed', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ('', '', ''),
#  ...]

# %%
from konlpy.tag import Kkma;

# %%
kkma = Kkma()

# %%
tokens_ko_pol = kkma.morphs(doc_ko_pol)

# %% [markdown]
# # 참고자료
# * [1] 파이썬으로 영어와 한국어 텍스트 다루기 - https://www.lucypark.kr/courses/2015-dm/text-mining.html
